# %%
import pandas as pd
import seaborn as sns
import pylab as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')

# %%
df = pd.read_csv("smoothness_and_volume.csv", index_col=0)

# %%
sns.pairplot(df)

# %%
df[pd.isnull(df.FWHMx_mm)]
# Out:
# Empty DataFrame
# Columns: [FWHMx_mm, FWHMy_mm, FWHMz_mm, volume_vox]
# Index: []

# %%
df.FWHMx_mm.argmin()
# Out:
# 2960

# %%
df[df.index == 8500]
# Out:
#       FWHMx_mm  FWHMy_mm  FWHMz_mm  volume_vox
# 8500   19.5945   20.7443   17.7696      157647

# %%
432
